# %%
import os
os.listdir("../../../../OneDrive - Western Michigan University/machine learning/project/datasets/state-ev-registration-data/")
path="../../../../OneDrive - Western Michigan University/machine learning/project/datasets/state-ev-registration-data/"

# %%
import pandas as pd

# %%
os.listdir(path)
# Out:
# ['wa_ev_registrations_public.csv',
#  '.DS_Store',
#  'NJ_EV_Registrations.csv',
#  'TX_EV_Registrations.csv',
#  'ca_ev_registrations_public.csv',
#  'OR_EV_Registrations.csv',
#  'wi_ev_registrations_public.csv',
#  'VT_EV_Registrations.csv',
#  'NY_EV_Registrations.csv',
#  'fl_ev_registrations_public.csv',
#  'MT_EV_Registrations.csv',
#  'CT_EV_Registrations.csv',
#  'MN_EV_Registrations.csv',
#  'TN_EV_Registrations.csv',
#  'va_ev_registrations_public.csv',
#  'CO_EV_Registrations.csv']

# %%
import pandas as pd
df_ca=pd.read_csv(path+"ca_ev_registrations_public.csv",low_memory=False)

# %%
df_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542443 entries, 0 to 2542442
# Data columns (total 9 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Vehicle ID                    object
#  1   County GEOID                  object
#  2   Registration Valid Date       object
#  3   DMV ID                        int64
#  4   DMV Snapshot                  object
#  5   Registration Expiration Date  float64
#  6   State Abbreviation            object
#  7   Geography                     object
#  8   Vehicle Name                  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 174.6+ MB

# %%
df_ca.sample(5)
# Out:
#                Vehicle ID County GEOID Registration Valid Date  DMV ID
# 2513973   CA-011-427401\r        06073              2020-01-01      11  \
# 1623377  CA-010-1609459\r        06037              2019-01-01      10
# 1738743  CA-010-1721866\r        06059              2019-01-01      10
# 2300452   CA-011-235515\r        06037              2020-01-01      11
# 377821    CA-008-773401\r        06013              2017-01-01       8
#
#                                       DMV Snapshot
# 2513973  CA Registration Data from CA (12/31/2020)  \
# 1623377  CA Registration Data from CA (12/31/2019)
# 1738743  CA Registration Data from CA (12/31/2019)
# 2300452  CA Registration Data from CA (12/31/2020)
# 377821   CA Registration Data from CA (12/31/2017)
#
#          Registration Expiration Date State Abbreviation Geography
# 2513973                           NaN                 CA    County  \
# 1623377                           NaN                 CA    County
# ...

# %%
df_ca["Vehicle Make"]=df_ca['Vehicle Name'].apply(lambda x: x.split()[0])
#convert a string to capital letters
df_ca["Vehicle Make"]=df_ca["Vehicle Make"].apply(lambda x: x.upper())
df_ca["Vehicle Model"]=df_ca['Vehicle Name'].apply(lambda x: " ".join(x.split()[1:]))

# %%
df_ca["Vehicle Make"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Vehicle Make'>

# %%
" ".join("Tesla Model S".split()[1:])
# join elemnts in a list with space
# Out:
# 'Model S'

# %%
df_ca["Vehicle Model"].value_counts().plot(kind="bar",figsize=(20,10))
# Out:
# <Axes: xlabel='Vehicle Model'>
